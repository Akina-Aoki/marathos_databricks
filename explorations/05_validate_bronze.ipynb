# %% [markdown]
# # Verify the data from the bronze layer

# %%
# %sql
SHOW TABLES IN marathos_catalog.bronze;

# %%
# %sql
SELECT COUNT(*) AS marathon_row_count
FROM marathos_catalog.bronze.raw_marathon_results;

# %%
# %sql
SELECT *
FROM marathos_catalog.bronze.raw_marathon_results
LIMIT 100;

# %%
# %sql
SELECT COUNT(*) AS country_code_row_count
FROM marathos_catalog.bronze.raw_country_codes;

# %%
# %sql
SELECT *
FROM marathos_catalog.bronze.raw_country_codes
LIMIT 100;
