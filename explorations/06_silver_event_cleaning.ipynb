# %% [markdown]
# # Marathos EDA from bronze layer to silver layer cleaning (EVENT)
#
# In this notebook, I cleaned and prepared the event-related columns for the Silver layer.
# ```
# - year_of_event
# - event_dates
# - event_name
# - event_distance_length
# - event_number_of_finishers
# ```
#
# Completed cleaning steps:
# - Converted raw column names to snake_case.
# - Validated year_of_event.
# - Parsed event_dates into event_start_date and event_end_date.
# - Removed invalid event date rows.
# - Trimmed event_name.
# - Removed invalid event_distance_length rows, including day-based events, malformed values, and multi-stage Etappen events.
# - Standardized event_distance_length values.
# - Extracted event_distance_value and event_distance_unit.
# - Removed rows where event_number_of_finishers was 0.
#
# The event columns are now ready to be combined with athlete cleaning rules later in the final Silver OBT..

# %%
# Load Bronze marathon table for Silver cleaning trial

marathon_bronze_df = spark.sql("""
    SELECT *
    FROM marathos_catalog.bronze.raw_marathon_results
""")

display(marathon_bronze_df)

# %%
print(f"Bronze marathon rows: {marathon_bronze_df.count()}")

# %%
marathon_bronze_df.columns

# %%
# imports
import re
from pyspark.sql.functions import col, when, count, to_date, try_to_date, expr, regexp_extract, concat, lit, trim, length, lower, regexp_replace

# %%
# Convert column names to snake_case
def to_snake_case(column_name):
    clean_name = column_name.strip().lower()
    clean_name = re.sub(r"[^a-z0-9]+", "_", clean_name)
    return clean_name.strip("_")


# Rename all dataframe columns
def rename_columns_to_snake_case(df):
    new_columns = [to_snake_case(column) for column in df.columns]
    return df.toDF(*new_columns)

# %%
# Create Silver trial dataframe with clean column names
marathon_silver_df = rename_columns_to_snake_case(marathon_bronze_df)

display(marathon_silver_df)

# %%
# Check new column names
marathon_silver_df.columns

# %% [markdown]
# ## 1. year_of_event
# - Check for NULLS again and cast to integer type

# %%
# Check nulls and year range
display(
    marathon_silver_df
    .select("year_of_event")
    .summary()
)

# %%
# Check if any event years are outside the expected dataset range
invalid_year_of_event_df = (
    marathon_silver_df
    .filter(
        (col("year_of_event").isNull()) |
        (col("year_of_event") < 1798) |
        (col("year_of_event") > 2022)
    )
)

print(f"Invalid year_of_event rows: {invalid_year_of_event_df.count()}")

# %%
# Cast year_of_event to integer
marathon_silver_df = marathon_silver_df.withColumn(
    "year_of_event",
    col("year_of_event").cast("int")
)

display(marathon_silver_df.select("year_of_event").summary())

# %% [markdown]
# #### Findings and Plan:
# - The year_of_event column has no missing values and the values are within the expected historical range of the dataset, from 1798 to 2022.
#
# - For the Silver layer, I cast year_of_event to integer to make the column consistent for filtering, aggregation, and later date/dimensional modelling.

# %% [markdown]
# ## 2.  event_dates
# - I have in my EDA different formats. Not good.
# ```
# 24.06.2017
# 12.-13.10.2019
# 31.12.-01.01.2018
# 28.12.2019-03.01.2020
# ```
#
# - Need to create new columns with these values:
# ```
# event_date_raw
# event_date_format_type
# event_start_date
# event_end_date
# ```

# %%
# Keep the original event_dates
marathon_silver_df = marathon_silver_df.withColumn(
    "event_date_raw",
    col("event_dates")
)

# Classify the different date formats found in EDA
event_dates_format_df = (
    marathon_silver_df
    .withColumn(
        "event_date_format_type",
        when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.\d{4}$"), "single_date")
        .when(col("event_dates").rlike(r"^\d{2}\.-\d{2}\.\d{2}\.\d{4}$"), "date_range_same_month")
        .when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.-\d{2}\.\d{2}\.\d{4}$"), "date_range_different_month")
        .when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.\d{4}-\d{2}\.\d{2}\.\d{4}$"), "date_range_different_year")
        .otherwise("unknown_format")
    )
    .groupBy("event_date_format_type")
    .agg(count("*").alias("row_count"))
    .orderBy(col("row_count").desc())
)

# confirms the format groups before parsing
display(event_dates_format_df)

# %%
# save the date format classification
# Keep original event date and classify the date format
marathon_silver_df = (
    marathon_silver_df
    .withColumn("event_date_raw", col("event_dates"))
    .withColumn(
        "event_date_format_type",
        when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.\d{4}$"), "single_date")
        .when(col("event_dates").rlike(r"^\d{2}\.-\d{2}\.\d{2}\.\d{4}$"), "date_range_same_month")
        .when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.-\d{2}\.\d{2}\.\d{4}$"), "date_range_different_month")
        .when(col("event_dates").rlike(r"^\d{2}\.\d{2}\.\d{4}-\d{2}\.\d{2}\.\d{4}$"), "date_range_different_year")
        .otherwise("unknown_format")
    )
)

display(
    marathon_silver_df.select(
        "event_dates",
        "event_date_raw",
        "event_date_format_type"
    )
)

# %%
# Parse simple single-date events into a proper date column
# Use try_to_date to handle invalid dates gracefully (returns NULL instead of error)
marathon_silver_df = marathon_silver_df.withColumn(
    "event_start_date",
    when(
        col("event_date_format_type") == "single_date",
        try_to_date(col("event_dates"), "dd.MM.yyyy")
    )
)

display(
    marathon_silver_df
    .filter(col("event_date_format_type") == "single_date")
    .select("event_dates", "event_date_format_type", "event_start_date")
)

# %% [markdown]
# #### look for malformed dates 00.06.1991

# %%
# Parse single-date events safely.
# Invalid dates, like 00.06.1991, become NULL instead of breaking the notebook.
marathon_silver_df = marathon_silver_df.withColumn(
    "event_start_date",
    when(
        col("event_date_format_type") == "single_date",
        expr("try_to_date(event_dates, 'dd.MM.yyyy')")
    )
)

display(
    marathon_silver_df
    .filter(col("event_date_format_type") == "single_date")
    .select("event_dates", "event_date_format_type", "event_start_date")
)

# %%
# Count single-date rows that could not be parsed
failed_single_date_parse_count = (
    marathon_silver_df
    .filter(
        (col("event_date_format_type") == "single_date") &
        (col("event_start_date").isNull())
    )
    .count()
)

print(f"Failed single_date parse rows: {failed_single_date_parse_count}")

# %%
# Inspect invalid single-date values
invalid_single_dates_df = (
    marathon_silver_df
    .filter(
        (col("event_date_format_type") == "single_date") &
        (col("event_start_date").isNull())
    )
    .select(
        "year_of_event",
        "event_dates",
        "event_name",
        "event_distance_length"
    )
    .distinct()
    .orderBy("event_dates")
)

display(invalid_single_dates_df)

# %% [markdown]
# - Some event_dates values match the expected single-date pattern but are not valid real dates.
# For example, 00.06.1991 has an invalid day value.
#
# - To prevent the Silver transformation from failing, I used try_to_date instead of to_date.
# - Invalid dates are converted to NULL and will be removed later because the event date is required for downstream analysis and date modelling.

# %% [markdown]
# #### parse date_range_same_month
# - from `03.-09.11.1991` to
# ```
# event_start_date = 1991-11-03
# event_end_date   = 1991-11-09
# ```

# %%
# Extract parts from same-month date ranges like 03.-09.11.1991
same_month_start_day = regexp_extract(col("event_dates"), r"^(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 1)
same_month_end_day = regexp_extract(col("event_dates"), r"^(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 2)
same_month_month = regexp_extract(col("event_dates"), r"^(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 3)
same_month_year = regexp_extract(col("event_dates"), r"^(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 4)

# Create temporary date strings for parsing
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "same_month_start_raw",
        concat(same_month_start_day, lit("."), same_month_month, lit("."), same_month_year)
    )
    .withColumn(
        "same_month_end_raw",
        concat(same_month_end_day, lit("."), same_month_month, lit("."), same_month_year)
    )
)

# Parse start date and end date safely
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "event_start_date",
        when(
            col("event_date_format_type") == "date_range_same_month",
            expr("try_to_date(same_month_start_raw, 'dd.MM.yyyy')")
        ).otherwise(col("event_start_date"))
    )
    .withColumn(
        "event_end_date",
        when(
            col("event_date_format_type") == "single_date",
            col("event_start_date")
        ).when(
            col("event_date_format_type") == "date_range_same_month",
            expr("try_to_date(same_month_end_raw, 'dd.MM.yyyy')")
        )
    )
)

display(
    marathon_silver_df
    .filter(col("event_date_format_type") == "date_range_same_month")
    .select(
        "event_dates",
        "same_month_start_raw",
        "same_month_end_raw",
        "event_start_date",
        "event_end_date"
    )
)

# %%
# Check same-month date ranges that failed to parse
failed_same_month_parse_count = (
    marathon_silver_df
    .filter(
        (col("event_date_format_type") == "date_range_same_month") &
        (
            col("event_start_date").isNull() |
            col("event_end_date").isNull()
        )
    )
    .count()
)

print(f"Failed date_range_same_month parse rows: {failed_same_month_parse_count}")

# %% [markdown]
# #### parse date_range_different_month

# %%
# Extract parts from different-month ranges like 31.12.-01.01.2018
diff_month_start_day = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 1)
diff_month_start_month = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 2)
diff_month_end_day = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 3)
diff_month_end_month = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 4)
diff_month_end_year = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.-(\d{2})\.(\d{2})\.(\d{4})$", 5)

# Build raw date strings for start and end dates
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "diff_month_start_raw",
        concat(
            diff_month_start_day,
            lit("."),
            diff_month_start_month,
            lit("."),
            when(
                diff_month_start_month.cast("int") > diff_month_end_month.cast("int"),
                diff_month_end_year.cast("int") - 1
            ).otherwise(diff_month_end_year)
        )
    )
    .withColumn(
        "diff_month_end_raw",
        concat(
            diff_month_end_day,
            lit("."),
            diff_month_end_month,
            lit("."),
            diff_month_end_year
        )
    )
)

# Parse different-month start and end dates safely
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "event_start_date",
        when(
            col("event_date_format_type") == "date_range_different_month",
            expr("try_to_date(diff_month_start_raw, 'dd.MM.yyyy')")
        ).otherwise(col("event_start_date"))
    )
    .withColumn(
        "event_end_date",
        when(
            col("event_date_format_type") == "date_range_different_month",
            expr("try_to_date(diff_month_end_raw, 'dd.MM.yyyy')")
        ).otherwise(col("event_end_date"))
    )
)

display(
    marathon_silver_df
    .filter(col("event_date_format_type") == "date_range_different_month")
    .select(
        "event_dates",
        "diff_month_start_raw",
        "diff_month_end_raw",
        "event_start_date",
        "event_end_date"
    )
)

# %%
# Check different-month date ranges that failed to parse
failed_diff_month_parse_count = (
    marathon_silver_df
    .filter(
        (col("event_date_format_type") == "date_range_different_month") &
        (
            col("event_start_date").isNull() |
            col("event_end_date").isNull()
        )
    )
    .count()
)

print(f"Failed date_range_different_month parse rows: {failed_diff_month_parse_count}")

# %% [markdown]
# #### parse date_range_different_year

# %%
# Extract parts from full date ranges like 28.12.2019-03.01.2020
diff_year_start_day = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 1)
diff_year_start_month = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 2)
diff_year_start_year = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 3)

diff_year_end_day = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 4)
diff_year_end_month = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 5)
diff_year_end_year = regexp_extract(col("event_dates"), r"^(\d{2})\.(\d{2})\.(\d{4})-(\d{2})\.(\d{2})\.(\d{4})$", 6)

# Build raw date strings for start and end dates
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "diff_year_start_raw",
        concat(
            diff_year_start_day,
            lit("."),
            diff_year_start_month,
            lit("."),
            diff_year_start_year
        )
    )
    .withColumn(
        "diff_year_end_raw",
        concat(
            diff_year_end_day,
            lit("."),
            diff_year_end_month,
            lit("."),
            diff_year_end_year
        )
    )
)

# Parse different-year start and end dates safely
marathon_silver_df = (
    marathon_silver_df
    .withColumn(
        "event_start_date",
        when(
            col("event_date_format_type") == "date_range_different_year",
            expr("try_to_date(diff_year_start_raw, 'dd.MM.yyyy')")
        ).otherwise(col("event_start_date"))
    )
    .withColumn(
        "event_end_date",
        when(
            col("event_date_format_type") == "date_range_different_year",
            expr("try_to_date(diff_year_end_raw, 'dd.MM.yyyy')")
        ).otherwise(col("event_end_date"))
    )
)

display(
    marathon_silver_df
    .filter(col("event_date_format_type") == "date_range_different_year")
    .select(
        "event_dates",
        "diff_year_start_raw",
        "diff_year_end_raw",
        "event_start_date",
        "event_end_date"
    )
)

# %%
# Check different-year date ranges that failed to parse
failed_diff_year_parse_count = (
    marathon_silver_df
    .filter(
        (col("event_date_format_type") == "date_range_different_year") &
        (
            col("event_start_date").isNull() |
            col("event_end_date").isNull()
        )
    )
    .count()
)

print(f"Failed date_range_different_year parse rows: {failed_diff_year_parse_count}")

# %% [markdown]
# - All event date formats are now parsed successfully except the 1002 invalid single-date rows found earlier.
# - Create event_start_date and event_end_date. Remove rows where event_start_date or event_end_date is NULL.

# %% [markdown]
# #### remove invalid parsed dates

# %%
# Count rows before removing invalid parsed dates
rows_before_date_cleaning = marathon_silver_df.count()

# Remove rows where parsed event dates are missing
marathon_silver_df = marathon_silver_df.filter(
    col("event_start_date").isNotNull() &
    col("event_end_date").isNotNull()
)

# Count rows after removing invalid parsed dates
rows_after_date_cleaning = marathon_silver_df.count()

print(f"Rows before date cleaning: {rows_before_date_cleaning}")
print(f"Rows after date cleaning: {rows_after_date_cleaning}")
print(f"Rows removed: {rows_before_date_cleaning - rows_after_date_cleaning}")

# %%
# Confirm no invalid parsed dates remain
invalid_event_date_count = (
    marathon_silver_df
    .filter(
        col("event_start_date").isNull() |
        col("event_end_date").isNull()
    )
    .count()
)

print(f"Invalid event date rows remaining: {invalid_event_date_count}")

# %% [markdown]
# - The event_dates column was parsed into event_start_date and event_end_date.
#
# - The dataset contained 1002 invalid date rows, such as dates with day value 00. These rows were removed because valid event dates are required for time-based analysis, dimensional modelling, and dashboard filtering.
#
# - After cleaning, no invalid parsed event dates remain.

# %% [markdown]
# ## 3. event_name
# Check again:
# 1. null values
# 2. empty strings
# 3. basic trimming

# %%
# Display invalid event_name rows, if any
invalid_event_name_df = (
    marathon_silver_df
    .filter(
        col("event_name").isNull() |
        (length(trim(col("event_name"))) == 0)
    )
    .select(
        "year_of_event",
        "event_dates",
        "event_name",
        "event_distance_length",
        "athlete_country"
    )
)

display(invalid_event_name_df)

# %%
# Remove extra spaces before/after event_name
marathon_silver_df = marathon_silver_df.withColumn(
    "event_name",
    trim(col("event_name"))
)

display(
    marathon_silver_df.select(
        "event_name"
    )
)

# %% [markdown]
# - The event_name column has no null or empty values.
# - For Silver, I trimmed event_name to remove possible leading or trailing spaces. This column will later be used to create event_id, which is needed for dimensional modelling.

# %% [markdown]
# ## 4. event_distance_length
# #### Silver Layer cleaning rules are:
# - if event has unit km or mi then performance should be in h
# - if event has unit h then performance should be in km
#
# **So there's 2 types of events:**
# - distance event: km / mi
# - time event: h
#
# **Keep valid for OBT:**
# - km
# - mi
# - h
# - k / K, but standardize to km
#
# **Remove invalid:**
# - Etappen / multi-stage events
# - d / days, for example 6d, 7d, 10d, 18d
# - None
# - malformed values like 07:35, 6:40, 71.5, 45.1m
#
# **Next task sequence after event_distance_length:**
# 1. Clean event_distance_length
# 2. Create event_type
# 3. Standardize event distance/unit
# 4. Validate athlete_performance against event_type

# %%
# Classify event_distance_length before cleaning
event_distance_type_df = (
    marathon_silver_df
    .withColumn(
        "event_distance_type",
        when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?km$"), "distance_km")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?mi$"), "distance_mi")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+h$"), "time_hours")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?k$"), "distance_k_needs_standardization")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+d$"), "days_invalid")
        .when(lower(trim(col("event_distance_length"))).contains("etappen"), "multi_stage_invalid")
        .otherwise("invalid_or_unknown")
    )
    .groupBy("event_distance_type")
    .agg(count("*").alias("row_count"))
    .orderBy(col("row_count").desc())
)

display(event_distance_type_df)

# %% [markdown]
# **keep:**
# - distance_km
# - distance_mi
# - time_hours
# - distance_k_needs_standardization
#
# **remove:**
# **Total** 92,021 + 12,131 + 5,096 = 109,248 rows
# - multi_stage_invalid
# - days_invalid
# - invalid_or_unknown

# %% [markdown]
# #### Remove invalid values

# %%
# Inspect invalid event_distance_length values before removing them
invalid_event_distance_df = (
    marathon_silver_df
    .withColumn(
        "event_distance_type",
        when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?km$"), "distance_km")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?mi$"), "distance_mi")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+h$"), "time_hours")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?k$"), "distance_k_needs_standardization")
        .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+d$"), "days_invalid")
        .when(lower(trim(col("event_distance_length"))).contains("etappen"), "multi_stage_invalid")
        .otherwise("invalid_or_unknown")
    )
    .filter(
        col("event_distance_type").isin(
            "multi_stage_invalid",
            "days_invalid",
            "invalid_or_unknown"
        )
    )
    .groupBy("event_distance_length", "event_distance_type")
    .agg(count("*").alias("row_count"))
    .orderBy(col("row_count").desc())
)

display(invalid_event_distance_df)

# %% [markdown]
# - invalid group is mostly multi-stage Etappen events, plus day-based events.

# %% [markdown]
# #### add event_distance_type to marathon_silver_df

# %%
# Add event distance classification to the main Silver dataframe
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_type",
    when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?km$"), "distance_km")
    .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?mi$"), "distance_mi")
    .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+h$"), "time_hours")
    .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+(\.[0-9]+)?k$"), "distance_k_needs_standardization")
    .when(lower(trim(col("event_distance_length"))).rlike(r"^[0-9]+d$"), "days_invalid")
    .when(lower(trim(col("event_distance_length"))).contains("etappen"), "multi_stage_invalid")
    .otherwise("invalid_or_unknown")
)

# %% [markdown]
# #### remove invalid event distance rows

# %%
# Count rows before filtering invalid event distance values
rows_before_event_distance_cleaning = marathon_silver_df.count()

# Keep only valid event distance types
marathon_silver_df = marathon_silver_df.filter(
    col("event_distance_type").isin(
        "distance_km",
        "distance_mi",
        "time_hours",
        "distance_k_needs_standardization"
    )
)

# Count rows after filtering
rows_after_event_distance_cleaning = marathon_silver_df.count()

print(f"Rows before event_distance_length cleaning: {rows_before_event_distance_cleaning}")
print(f"Rows after event_distance_length cleaning: {rows_after_event_distance_cleaning}")
print(f"Rows removed: {rows_before_event_distance_cleaning - rows_after_event_distance_cleaning}")

# %% [markdown]
# #### standardize k/K values to km

# %%
# Standardize values like 50K or 160k to 50km / 160km
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_length",
    when(
        col("event_distance_type") == "distance_k_needs_standardization",
        regexp_replace(lower(trim(col("event_distance_length"))), "k$", "km")
    ).otherwise(trim(col("event_distance_length")))
)

# Reclassify standardized k/K values as distance_km
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_type",
    when(col("event_distance_type") == "distance_k_needs_standardization", "distance_km")
    .otherwise(col("event_distance_type"))
)

display(
    marathon_silver_df
    .select("event_distance_length", "event_distance_type")
    .distinct()
    .orderBy("event_distance_length")
)

# %% [markdown]
# - For event_distance_length, I kept only event types that can be consistently validated against athlete_performance.
#
# - I kept km, mi, and h events.
# - Values ending in k or K were standardized to km.
#
# - 109,248 invalid event distance rows
# - I removed invalid rows, including day-based events ending in d, malformed or unknown values, and multi-stage Etappen events.

# %% [markdown]
# #### extract event distance value and unit
# **create cleaner columns from event_distance_length:**
# ```
# event_distance_value
# event_distance_unit
# ```
#
# **Sample:**
# ```
# 100km → value = 100, unit = km
# 69mi  → value = 69,  unit = mi
# 6h    → value = 6,   unit = h
# ```

# %%
# Extract numeric distance/time value from event_distance_length
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_value",
    regexp_extract(col("event_distance_length"), r"^([0-9]+(\.[0-9]+)?)", 1).cast("double")
)

# Extract event unit: km, mi, or h
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_unit",
    regexp_extract(col("event_distance_length"), r"(km|mi|h)$", 1)
)

display(
    marathon_silver_df
    .select(
        "event_distance_length",
        "event_distance_type",
        "event_distance_value",
        "event_distance_unit"
    )
    .distinct()
    .orderBy("event_distance_value")
)

# %%
# Check if distance value or unit failed to extract
invalid_event_distance_extraction_count = (
    marathon_silver_df
    .filter(
        col("event_distance_value").isNull() |
        col("event_distance_unit").isNull() |
        (col("event_distance_unit") == "")
    )
    .count()
)

print(f"Invalid event distance extraction rows: {invalid_event_distance_extraction_count}")

# %% [markdown]
# #### Check the 1931 rows that failed to be standardized
# - some values have uppercase Km but my extraction looked only for lowercases
# - standardize event_distance_length to lowercase before extracting the value and unit.

# %%
# Inspect rows where event distance value or unit failed to extract
invalid_event_distance_extraction_df = (
    marathon_silver_df
    .filter(
        col("event_distance_value").isNull() |
        col("event_distance_unit").isNull() |
        (col("event_distance_unit") == "")
    )
    .groupBy("event_distance_length", "event_distance_type")
    .agg(count("*").alias("row_count"))
    .orderBy(col("row_count").desc())
)

display(invalid_event_distance_extraction_df)

# %% [markdown]
# #### standardize event_distance_length

# %%
# Standardize event_distance_length text before extracting value and unit
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_length",
    lower(trim(col("event_distance_length")))
)

# %% [markdown]
# #### re-extract value and unit

# %%
# Extract numeric value from event_distance_length
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_value",
    regexp_extract(col("event_distance_length"), r"^([0-9]+(\.[0-9]+)?)", 1).cast("double")
)

# Extract unit: km, mi, or h
marathon_silver_df = marathon_silver_df.withColumn(
    "event_distance_unit",
    regexp_extract(col("event_distance_length"), r"(km|mi|h)$", 1)
)

# %%
# Check if value or unit still failed to extract
invalid_event_distance_extraction_count = (
    marathon_silver_df
    .filter(
        col("event_distance_value").isNull() |
        col("event_distance_unit").isNull() |
        (col("event_distance_unit") == "")
    )
    .count()
)

print(f"Invalid event distance extraction rows: {invalid_event_distance_extraction_count}")

# %% [markdown]
# #### Result of cleaned event_distance_length

# %%
# Display cleaned event distance columns
display(
    marathon_silver_df
    .select(
        "event_distance_length",
        "event_distance_type",
        "event_distance_value",
        "event_distance_unit"
    )
    .distinct()
    .orderBy("event_distance_value", "event_distance_unit")
)

# %%
# Count remaining event distance types after cleaning
display(
    marathon_silver_df
    .groupBy("event_distance_type", "event_distance_unit")
    .agg(count("*").alias("row_count"))
    .orderBy("event_distance_type", "event_distance_unit")
)

# %% [markdown]
# #### Silver Layer Cleaning Rule for `event_distance_length`
# - The event_distance_length column was cleaned and standardized.
#
# - Invalid rows were removed, including day-based events, multi-stage Etappen events, and malformed or unknown values. Values with inconsistent casing such as 45Km were standardized to lowercase.
#
# - I extracted the numeric event value and event unit into separate columns:
#     - event_distance_value
#     - event_distance_unit
#
# - After cleaning, no rows failed event distance extraction.

# %% [markdown]
# ## 5. `event_number_of_finishers`
# From my raw eda for this column, I have these findings and I made this decision:
# ```
# Null values: 0
# Rows with 0 finishers: 10
# ```
#
# ---
#
# **Zero finishers check**
# - I found **10 rows** where `Event number of finishers` is `0`.
# - Since this column represents how many athletes finished an event, a value of `0` may indicate incomplete, invalid, or unusual event records.
# - Because there are only 10 such rows in a dataset with over 7 million rows, I will document them during EDA and decide in the Silver layer that they should be removed.

# %% [markdown]
# #### Display rows with invalid finisher counts and remove

# %%
# Display rows with invalid finisher counts
display(
    marathon_silver_df
    .filter(
        col("event_number_of_finishers").isNull() |
        (col("event_number_of_finishers") <= 0)
    )
    .select(
        "year_of_event",
        "event_dates",
        "event_name",
        "event_distance_length",
        "event_number_of_finishers",
        "athlete_performance",
        "athlete_country"
    )
)

# %%
# Remove rows where finisher count is missing or zero
rows_before_finisher_cleaning = marathon_silver_df.count()

marathon_silver_df = marathon_silver_df.filter(
    col("event_number_of_finishers").isNotNull() &
    (col("event_number_of_finishers") > 0)
)

rows_after_finisher_cleaning = marathon_silver_df.count()

print(f"Rows before finisher cleaning: {rows_before_finisher_cleaning}")
print(f"Rows after finisher cleaning: {rows_after_finisher_cleaning}")
print(f"Rows removed: {rows_before_finisher_cleaning - rows_after_finisher_cleaning}")

# %%
# Confirm no invalid finisher rows remain
invalid_finishers_remaining = (
    marathon_silver_df
    .filter(
        col("event_number_of_finishers").isNull() |
        (col("event_number_of_finishers") <= 0)
    )
    .count()
)

print(f"Invalid event_number_of_finishers rows remaining: {invalid_finishers_remaining}")

# %% [markdown]
# #### Rules made for `event_number_of_finishers` in silver layer:
# - The event_number_of_finishers column has no null values, but the raw EDA found 10 rows where the value is 0.
#
# - Since this column represents the number of athletes who finished an event, 0 finishers indicates an invalid or incomplete event record. Because there are only a few such rows, I removed them in the Silver layer.
#
# - After cleaning, event_number_of_finishers only contains positive values.

# %% [markdown]
# ## Display the cleaned event columns after Silver cleaning steps

# %%
# Check all current columns and data types
marathon_silver_df.printSchema()

# %% [markdown]
# #### event dates Types Summary
# - These will be used for filtering by date, year/month/day extraction, date dimension, dashboard time filters and gold aggregations so they're **date** types.
# ```
# event_start_date: date
# event_end_date: date
# ```
#
# - These are **string** types because they preserve the original raw value from Bronze, for traceability.
# ```
# event_dates: string
# event_date_raw: string
# ```

# %%
# Check current row count after event-focused cleaning
print(f"Rows after event column cleaning: {marathon_silver_df.count()}")

# %%
# Display the cleaned event columns after Silver cleaning steps
display(
    marathon_silver_df
    .select(
        "year_of_event",
        "event_start_date",
        "event_end_date",
        "event_name",
        "event_distance_length",
        "event_distance_type",
        "event_distance_value",
        "event_distance_unit",
        "event_number_of_finishers"
    )
    .limit(100)
)

# %% [markdown]
# - **Must be removed**
# They helped test the cleaning, but they should not stay in the final Silver OBT.
# ```
# same_month_start_raw
# same_month_end_raw
# diff_month_start_raw
# diff_month_end_raw
# diff_year_start_raw
# diff_year_end_raw
# ```

# %%
# Drop temporary columns used only for parsing event date ranges
marathon_silver_df = marathon_silver_df.drop(
    "same_month_start_raw",
    "same_month_end_raw",
    "diff_month_start_raw",
    "diff_month_end_raw",
    "diff_year_start_raw",
    "diff_year_end_raw"
)

# Check schema after dropping helper columns
marathon_silver_df.printSchema()
