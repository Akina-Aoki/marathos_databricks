-- %%
SHOW CATALOGS;

-- create catalog
CREATE CATALOG IF NOT EXISTS marathos_catalog;

-- use existing catalogs
USE CATALOG marathos_catalog;

-- create schema layers
CREATE SCHEMA IF NOT EXISTS bronze;

CREATE SCHEMA IF NOT EXISTS silver;

CREATE SCHEMA IF NOT EXISTS gold;

CREATE SCHEMA IF NOT EXISTS default;

-- Create raw volume inside default schema
CREATE VOLUME IF NOT EXISTS default.raw;

-- validate my setups
SHOW SCHEMAS IN marathos_catalog;
SHOW VOLUMES IN marathos_catalog.default;

-- verification
SHOW VOLUMES IN marathos_catalog.default;
